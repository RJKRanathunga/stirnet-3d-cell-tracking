# %% [markdown]
# # Pipeline replay and diagnostic workbench
# This notebook is intentionally a thin client around the canonical replay package.

# %%
import napari
from src.io import PipelinePaths
from diagnostics.pipeline_replay.napari_widget import add_pipeline_replay_workbench

paths = PipelinePaths.discover()
viewer = napari.Viewer(ndisplay=3)
workbench = add_pipeline_replay_workbench(
    viewer, scenes_root=paths.tracking_scenes, pipeline_paths=paths
)
napari.run()
